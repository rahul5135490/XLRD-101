# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.style

# %%
import matplotlib.pyplot as plt

# %%
import xlrd

# %%
df = pd.ExcelFile(r'C:\Users\rcmlp.12\Desktop\misc\chaid decision tree\Aircraft_analysis_for DT_nodes_31jan22(doubt) (1).xlsx')

# %%
df.sheet_names
# Out:
# ['final', 'Sheet1', 'Sheet2']

# %%
a=df.parse('final')
a
# Out:
#     Row Labels  Target  202110_int  202111_int  202112_int  Q1_int  Q2_int  \
# 0       N1013A       0           1           1           1       4       2
# 1       N1093A       0           2           0           0       4       7
# 2       N1181A       0           1           3           2       7       5
# 3       N1229A       0           3           4           1       5       6
# 4       N1321A       0           3           3           0       8       6
# ..         ...     ...         ...         ...         ...     ...     ...
# 102     N855GT       0           1           1           1       2       2
# 103     N856GT       0           3           2           1       3       9
# 104     N857GT       0           3           2           0       4      10
# 105     N858GT       0           1           1           3      11       4
# 106     N859GT       0           3           0           0       8      12
#
# ...
